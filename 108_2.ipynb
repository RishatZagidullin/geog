# %% [markdown]
# # Задание 1
#
# 1. Программа просит ввести 2 числа (пусть будет n и m)
# 2. Далее на экран выводятся 100 действительных чисел от n до m, равноудаленных друг от друга.

# %% [markdown]
# # Задание 2
#
# 1. Создать массив из случайных целых чисел от 0 до 9 (назовем его total_array)
# 2. Вывести на экран сколько в массиве нулей, единичек, двоек и так далее.

# %% [markdown]
# # Задание 3
#
# 1. Создать случайную матрицу (10 на 10)
# 2. Отзеркалить ее по середине по вертикали (без использования вспомогательных функций)

# %% [markdown]
# # Задание 4
#
# 1. Создать случайный одномерный массив (от -4.5 до 2.5, 100 чисел)
# 2. Все отрицательные числа числа возвести в квадрат
# 3. Вывести на экран массив до возведения и после

# %% [markdown]
# # Задание 5
#
# 1. Создать два вектора длины 7.
# 2. Перемножить их (должна получиться матрица 7 на 7).
# 3. Можно (но необязательно) пользоваться библиотечными функциями.

# %% [markdown]
# # Задание 6
#
# 1. создать **ФУНКЦИЮ(!)** которая принимает аругментом 1 целое число (пусть будет n).
# 2. далее функция возвращает n-ый элемент последовательности Фибоначи.
# 3. вызвать данную функцию и вывести на экран результат.
# 4. если непонятно как сделать это в виде функции, тогда можно делать как обычно.

# %% [markdown]
# # Задание 7
#
# 1. Погуглить про np.random.
# 2. Сделать обзор (что это такое, какие функции там имеются) на этот модуль (но пишите только то, что вам самим понятно).
#
#
# **ОТВЕТ НАПИСАТЬ НИЖЕ**
#
# **ВОТ ТУТ**

# %% [markdown]
# # Задание 8
#
# 1. Загрузить картинку.
# 2. Создать из нее две картинки: у первой все, что выше главной диагонали белое, у второй - все, что ниже главной диагонали.
# 3. Сохранить обе полученные картинки.

# %% [markdown]
# # Задание 9
#
# 1. Вывести на экран случайно сгенерированный шум в виде матрицы функцией `plt.imshow()`.

# %% [markdown]
# # Задание 10
#
# 1. Погуглить про `matplotlib.pyplot`.
# 2. Сделать обзор (что это такое, какие функции там имеются) на этот модуль (но пишите только то, что вам самим понятно).
#
#
# **ОТВЕТ НАПИСАТЬ НИЖЕ**
#
# **ВОТ ТУТ**
