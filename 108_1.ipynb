# %% [markdown]
# # Task 1
#
# 1. Написать программу которая просит ввести два числа.
# 2. Затем пограмма возвращает бОльшее число, и то насколько это число больше.

# %% [markdown]
# # Task 2
#
# 1. Написать программу которая просит ввести положительное число (пусть будет n).
# 2. Затем пограмма создает матрицу порядка n со случайными числами и выводит ее на экран.

# %% [markdown]
# # Task 3
#
# 1. Построить график эллипса с помощью matplotlib.

# %% [markdown]
# # Task 4
#
# 1. Создать массив из 100 случайных целых чисел от -5 до 3.
# 2. Сложить только положительные элементы массива и вывести это число на экран.

# %% [markdown]
# # Task 5
#
# 1. Создать случайную матрицу 6 на 6.
# 2. Посчитать сумму элементов ее побочной диагонали.

# %% [markdown]
# # Task 6
#
# 1. создать ФУНКЦИЮ(!) которая принимает аругментом 1 целое число (пусть будет n).
# 2. далее функция возвращает n-ый элемент последовательности Фибоначи.
# 3. вызвать данную функцию и вывести на экран результат.
# 4. если непонятно как сделать это в виде функции, тогда можно делать как обычно.

# %% [markdown]
# # Task 7
#
# 1. Погуглить про np.random.
# 2. Сделать обзор (что это такое, какие функции там имеются) на этот модуль (но пишите только то, что вам самим понятно).
#
# ОТВЕТ НАПИСАТЬ НИЖЕ
#
# **ВОТ ТУТ**

# %% [markdown]
# # Task 8¶
#
# 1. Загрузить картинку.
# 2. Создать из нее две картинки: у первой все, что выше главной диагонали белое, у второй - все, что ниже главной диагонали.
# 3. Сохранить обе полученные картинки.

# %% [markdown]
# # Task 9
#
# 1. Вывести на экран случайно сгенерированный шум в виде матрицы функцией plt.imshow().

# %% [markdown]
# # Task 10
#
# 1. Погуглить про matplotlib.pyplot.
# 2. Сделать обзор (что это такое, какие функции там имеются) на этот модуль (но пишите только то, что вам самим понятно).
#
# ОТВЕТ НАПИСАТЬ НИЖЕ
#
# **ВОТ ТУТ**
